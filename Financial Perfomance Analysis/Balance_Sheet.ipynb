# %% [markdown]
# ## **Retrieve Balance Sheet Data**

# %%
import pandas as Pd

# %%
import requests
BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/MSFT?limit=5&apikey=86d3cec1f9b593a5c36ffc1339924f8f').json()
BS
# Out:
# [{'acceptedDate': '2020-07-30 20:44:46',
#   'accountPayables': 12530000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -43197000000,
#   'cashAndCashEquivalents': 13576000000,
#   'cashAndShortTermInvestments': 136527000000,
#   'commonStock': 80552000000,
#   'date': '2020-06-30',
#   'deferredRevenue': 36000000000,
#   'deferredRevenueNonCurrent': 3180000000,
#   'deferredTaxLiabilitiesNonCurrent': 204000000,
#   'fillingDate': '2020-07-30',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459020034944/msft-10k_20200630.htm',
#   'goodwill': 43351000000,
#   'goodwillAndIntangibleAssets': 50389000000,
#   'intangibleAssets': 7038000000,
#   'inventory': 1895000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459020034944/0001564590-20-034944-index.htm',
#   'longTermDebt': 59578000000,
#   'longTermInvestments': 0,
#   'netDebt': 49751000000,
#   'netReceivables': 32011000000,
#   'otherAssets': 11482000000,
#   'otherCurrentAssets': 11482000000,
#   'otherCurrentLiabilities': 10027000000,
#   'otherLiabilities': 10027000000,
#   'otherNonCurrentAssets': 13138000000,
#   'otherNonCurrentLiabilities': 10632000000,
#   'othertotalStockholdersEquity': 0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 44151000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 34566000000,
#   'shortTermDebt': 3749000000,
#   'shortTermInvestments': 122951000000,
#   'symbol': 'MSFT',
#   'taxAssets': 0,
#   'taxPayables': 0,
#   'totalAssets': 301311000000,
#   'totalCurrentAssets': 181915000000,
#   'totalCurrentLiabilities': 72310000000,
#   'totalDebt': 63327000000,
#   'totalInvestments': 0,
#   'totalLiabilities': 183007000000,
#   'totalLiabilitiesAndStockholdersEquity': 301311000000,
#   'totalNonCurrentAssets': 119396000000,
#   'totalNonCurrentLiabilities': 110697000000,
#   'totalStockholdersEquity': 118304000000},
#  {'acceptedDate': '2019-08-01 16:09:55',
#   'accountPayables': 9382000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -35330000000,
#   'cashAndCashEquivalents': 11356000000,
#   'cashAndShortTermInvestments': 133819000000,
#   'commonStock': 78520000000,
#   'date': '2019-06-30',
#   'deferredRevenue': 32676000000,
#   'deferredRevenueNonCurrent': 4530000000,
#   'deferredTaxLiabilitiesNonCurrent': 233000000,
#   'fillingDate': '2019-08-01',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459019027952/msft-10k_20190630.htm',
#   'goodwill': 42026000000,
#   'goodwillAndIntangibleAssets': 49776000000,
#   'intangibleAssets': 7750000000,
#   'inventory': 2063000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459019027952/0001564590-19-027952-index.htm',
#   'longTermDebt': 66662000000,
#   'longTermInvestments': 2649000000,
#   'netDebt': 60822000000,
#   'netReceivables': 29524000000,
#   'otherAssets': 10146000000,
#   'otherCurrentAssets': 10146000000,
#   'otherCurrentLiabilities': 9351000000,
#   'otherLiabilities': 9351000000,
#   'otherNonCurrentAssets': 14723000000,
#   'otherNonCurrentLiabilities': 7581000000,
#   'othertotalStockholdersEquity': 0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 36477000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 24150000000,
#   'shortTermDebt': 5516000000,
#   'shortTermInvestments': 122463000000,
#   'symbol': 'MSFT',
#   'taxAssets': 0,
#   'taxPayables': 0,
#   'totalAssets': 286556000000,
#   'totalCurrentAssets': 175552000000,
#   'totalCurrentLiabilities': 69420000000,
#   'totalDebt': 72178000000,
#   'totalInvestments': 0,
#   'totalLiabilities': 184226000000,
#   'totalLiabilitiesAndStockholdersEquity': 286556000000,
#   'totalNonCurrentAssets': 111004000000,
#   'totalNonCurrentLiabilities': 114806000000,
#   'totalStockholdersEquity': 102330000000},
#  {'acceptedDate': '2018-08-03 11:03:33',
#   'accountPayables': 8617000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -29223000000,
#   'cashAndCashEquivalents': 11946000000,
#   'cashAndShortTermInvestments': 133768000000,
#   'commonStock': 71223000000,
#   'date': '2018-06-30',
#   'deferredRevenue': 28905000000,
#   'deferredRevenueNonCurrent': 3815000000,
#   'deferredTaxLiabilitiesNonCurrent': 541000000,
#   'fillingDate': '2018-08-03',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459018019062/msft-10k_20180630.htm',
#   'goodwill': 35683000000,
#   'goodwillAndIntangibleAssets': 43736000000,
#   'intangibleAssets': 8053000000,
#   'inventory': 2662000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459018019062/0001564590-18-019062-index.htm',
#   'longTermDebt': 72242000000,
#   'longTermInvestments': 1862000000,
#   'netDebt': 64294000000,
#   'netReceivables': 26481000000,
#   'otherAssets': 6751000000,
#   'otherCurrentAssets': 6751000000,
#   'otherCurrentLiabilities': 8744000000,
#   'otherLiabilities': 8744000000,
#   'otherNonCurrentAssets': 7442000000,
#   'otherNonCurrentLiabilities': 5211000000,
#   'othertotalStockholdersEquity': 0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 29460000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 13682000000,
#   'shortTermDebt': 3998000000,
#   'shortTermInvestments': 121822000000,
#   'symbol': 'MSFT',
#   'taxAssets': 0,
#   'taxPayables': 0,
#   'totalAssets': 258848000000,
#   'totalCurrentAssets': 169662000000,
#   'totalCurrentLiabilities': 58488000000,
#   'totalDebt': 76240000000,
#   'totalInvestments': 0,
#   'totalLiabilities': 176130000000,
#   'totalLiabilitiesAndStockholdersEquity': 258848000000,
#   'totalNonCurrentAssets': 89186000000,
#   'totalNonCurrentLiabilities': 117642000000,
#   'totalStockholdersEquity': 82718000000},
#  {'acceptedDate': '2017-08-02 16:15:01',
#   'accountPayables': 7390000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -24179000000,
#   'cashAndCashEquivalents': 7663000000,
#   'cashAndShortTermInvestments': 132981000000,
#   'commonStock': 69315000000,
#   'date': '2017-06-30',
#   'deferredRevenue': 34102000000,
#   'deferredRevenueNonCurrent': 10377000000,
#   'deferredTaxLiabilitiesNonCurrent': 531000000,
#   'fillingDate': '2017-08-02',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000156459017014900/msft-10k_20170630.htm',
#   'goodwill': 35122000000,
#   'goodwillAndIntangibleAssets': 45228000000,
#   'intangibleAssets': 10106000000,
#   'inventory': 2181000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000156459017014900/0001564590-17-014900-index.htm',
#   'longTermDebt': 76073000000,
#   'longTermInvestments': 6023000000,
#   'netDebt': 78531000000,
#   'netReceivables': 19792000000,
#   'otherAssets': 4897000000,
#   'otherCurrentAssets': 4897000000,
#   'otherCurrentLiabilities': 6280000000,
#   'otherLiabilities': 6280000000,
#   'otherNonCurrentAssets': 6250000000,
#   'otherNonCurrentLiabilities': 17184000000,
#   'othertotalStockholdersEquity': 0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 23734000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 2648000000,
#   'shortTermDebt': 10121000000,
#   'shortTermInvestments': 125318000000,
#   'symbol': 'MSFT',
#   'taxAssets': 0,
#   'taxPayables': 0,
#   'totalAssets': 241086000000,
#   'totalCurrentAssets': 159851000000,
#   'totalCurrentLiabilities': 64527000000,
#   'totalDebt': 86194000000,
#   'totalInvestments': 0,
#   'totalLiabilities': 168692000000,
#   'totalLiabilitiesAndStockholdersEquity': 241086000000,
#   'totalNonCurrentAssets': 81235000000,
#   'totalNonCurrentLiabilities': 104165000000,
#   'totalStockholdersEquity': 72394000000},
#  {'acceptedDate': '2016-07-28 16:12:18',
#   'accountPayables': 6898000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -19800000000,
#   'cashAndCashEquivalents': 6510000000,
#   'cashAndShortTermInvestments': 113240000000,
#   'commonStock': 68178000000,
#   'date': '2016-06-30',
#   'deferredRevenue': 27468000000,
#   'deferredRevenueNonCurrent': 6441000000,
#   'deferredTaxLiabilitiesNonCurrent': 1476000000,
#   'fillingDate': '2016-07-28',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/789019/000119312516662209/d187868d10k.htm',
#   'goodwill': 17872000000,
#   'goodwillAndIntangibleAssets': 21605000000,
#   'intangibleAssets': 3733000000,
#   'inventory': 2251000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/789019/000119312516662209/0001193125-16-662209-index.htm',
#   'longTermDebt': 40783000000,
#   'longTermInvestments': 10431000000,
#   'netDebt': 47177000000,
#   'netReceivables': 18277000000,
#   'otherAssets': 5892000000,
#   'otherCurrentAssets': 5892000000,
#   'otherCurrentLiabilities': 5949000000,
#   'otherLiabilities': 5949000000,
#   'otherNonCurrentAssets': 3642000000,
#   'otherNonCurrentLiabilities': 13640000000,
#   'othertotalStockholdersEquity': 0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 18356000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 2282000000,
#   'shortTermDebt': 12904000000,
#   'shortTermInvestments': 106730000000,
#   'symbol': 'MSFT',
#   'taxAssets': 0,
#   'taxPayables': 0,
#   'totalAssets': 193694000000,
#   'totalCurrentAssets': 139660000000,
#   'totalCurrentLiabilities': 59357000000,
#   'totalDebt': 53687000000,
#   'totalInvestments': 0,
#   'totalLiabilities': 121697000000,
#   'totalLiabilitiesAndStockholdersEquity': 193694000000,
#   'totalNonCurrentAssets': 54034000000,
#   'totalNonCurrentLiabilities': 62340000000,
#   'totalStockholdersEquity': 71997000000}]

# %%
BS = pd.DataFrame.from_dict(BS)
BS
# Out:
#          date  ...                                          finalLink
# 0  2020-06-30  ...  https://www.sec.gov/Archives/edgar/data/789019...
# 1  2019-06-30  ...  https://www.sec.gov/Archives/edgar/data/789019...
# 2  2018-06-30  ...  https://www.sec.gov/Archives/edgar/data/789019...
# 3  2017-06-30  ...  https://www.sec.gov/Archives/edgar/data/789019...
# 4  2016-06-30  ...  https://www.sec.gov/Archives/edgar/data/789019...
#
# [5 rows x 47 columns]

# %%
BS.columns
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate',
#        'period', 'cashAndCashEquivalents', 'shortTermInvestments',
#        'cashAndShortTermInvestments', 'netReceivables', 'inventory',
#        'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
#        'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
#        'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
#        'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
#        'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
#        'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
#        'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
#        'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
#        'otherLiabilities', 'totalLiabilities', 'commonStock',
#        'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
#        'totalDebt', 'netDebt', 'link', 'finalLink'],
#       dtype='object')

# %%
BS_our_Columns =['date', 'symbol', 'cashAndCashEquivalents', 'shortTermInvestments',
       'cashAndShortTermInvestments', 'netReceivables', 'inventory',
       'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
       'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
       'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
       'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
       'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
       'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
       'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
       'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
       'otherLiabilities', 'totalLiabilities', 'commonStock',
       'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
       'othertotalStockholdersEquity', 'totalStockholdersEquity',
       'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
       'totalDebt', 'netDebt']

# %%
BS = BS[BS_our_Columns]
BS = BS.T

# %%
BS.columns = BS.iloc[0]
BS
# Out:
# date                                       2020-06-30  ...    2016-06-30
# date                                       2020-06-30  ...    2016-06-30
# symbol                                           MSFT  ...          MSFT
# cashAndCashEquivalents                    13576000000  ...    6510000000
# shortTermInvestments                     122951000000  ...  106730000000
# cashAndShortTermInvestments              136527000000  ...  113240000000
# netReceivables                            32011000000  ...   18277000000
# inventory                                  1895000000  ...    2251000000
# otherCurrentAssets                        11482000000  ...    5892000000
# totalCurrentAssets                       181915000000  ...  139660000000
# propertyPlantEquipmentNet                 44151000000  ...   18356000000
# goodwill                                  43351000000  ...   17872000000
# intangibleAssets                           7038000000  ...    3733000000
# goodwillAndIntangibleAssets               50389000000  ...   21605000000
# longTermInvestments                                 0  ...   10431000000
# taxAssets                                           0  ...             0
# otherNonCurrentAssets                     13138000000  ...    3642000000
# totalNonCurrentAssets                    119396000000  ...   54034000000
# otherAssets                               11482000000  ...    5892000000
# totalAssets                              301311000000  ...  193694000000
# accountPayables                           12530000000  ...    6898000000
# shortTermDebt                              3749000000  ...   12904000000
# taxPayables                                         0  ...             0
# deferredRevenue                           36000000000  ...   27468000000
# otherCurrentLiabilities                   10027000000  ...    5949000000
# totalCurrentLiabilities                   72310000000  ...   59357000000
# longTermDebt                              59578000000  ...   40783000000
# deferredRevenueNonCurrent                  3180000000  ...    6441000000
# deferredTaxLiabilitiesNonCurrent            204000000  ...    1476000000
# otherNonCurrentLiabilities                10632000000  ...   13640000000
# totalNonCurrentLiabilities               110697000000  ...   62340000000
# otherLiabilities                          10027000000  ...    5949000000
# totalLiabilities                         183007000000  ...  121697000000
# commonStock                               80552000000  ...   68178000000
# retainedEarnings                          34566000000  ...    2282000000
# accumulatedOtherComprehensiveIncomeLoss  -43197000000  ...  -19800000000
# othertotalStockholdersEquity                        0  ...             0
# totalStockholdersEquity                  118304000000  ...   71997000000
# totalLiabilitiesAndStockholdersEquity    301311000000  ...  193694000000
# totalInvestments                                    0  ...             0
# totalDebt                                 63327000000  ...   53687000000
# netDebt                                   49751000000  ...   47177000000
#
# [41 rows x 5 columns]

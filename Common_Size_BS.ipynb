# %% [markdown]
# <a href="https://colab.research.google.com/github/rekharchandran/Financial-Perfomance-Analysis-/blob/main/Common_Size_BS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import requests
BS = requests.get(f'https://financialmodelingprep.com/api/v3/balance-sheet-statement/AAPL?limit=5&apikey=86d3cec1f9b593a5c36ffc1339924f8f').json()
BS
# Out:
# [{'acceptedDate': '2020-10-29 18:06:25',
#   'accountPayables': 42296000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -66760000000,
#   'cashAndCashEquivalents': 38016000000,
#   'cashAndShortTermInvestments': 90943000000,
#   'commonStock': 50779000000,
#   'date': '2020-09-26',
#   'deferredRevenue': 6643000000,
#   'deferredRevenueNonCurrent': 0.0,
#   'deferredTaxLiabilitiesNonCurrent': 0.0,
#   'fillingDate': '2020-10-30',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/aapl-20200926.htm',
#   'goodwill': 0.0,
#   'goodwillAndIntangibleAssets': 0.0,
#   'intangibleAssets': 0.0,
#   'inventory': 4061000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019320000096/0000320193-20-000096-index.htm',
#   'longTermDebt': 98667000000,
#   'longTermInvestments': 0.0,
#   'netDebt': 74420000000,
#   'netReceivables': 37445000000,
#   'otherAssets': 11264000000,
#   'otherCurrentAssets': 11264000000,
#   'otherCurrentLiabilities': 42684000000,
#   'otherLiabilities': 42684000000,
#   'otherNonCurrentAssets': 42522000000,
#   'otherNonCurrentLiabilities': 26320000000,
#   'othertotalStockholdersEquity': 0.0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 36766000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 14966000000,
#   'shortTermDebt': 13769000000,
#   'shortTermInvestments': 52927000000,
#   'symbol': 'AAPL',
#   'taxAssets': 0.0,
#   'taxPayables': 0.0,
#   'totalAssets': 323888000000,
#   'totalCurrentAssets': 143713000000,
#   'totalCurrentLiabilities': 105392000000,
#   'totalDebt': 112436000000,
#   'totalInvestments': 0.0,
#   'totalLiabilities': 258549000000,
#   'totalLiabilitiesAndStockholdersEquity': 323888000000,
#   'totalNonCurrentAssets': 180175000000,
#   'totalNonCurrentLiabilities': 153157000000,
#   'totalStockholdersEquity': 65339000000},
#  {'acceptedDate': '2019-10-30 18:12:36',
#   'accountPayables': 46236000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -58579000000,
#   'cashAndCashEquivalents': 48844000000,
#   'cashAndShortTermInvestments': 100557000000,
#   'commonStock': 45174000000,
#   'date': '2019-09-28',
#   'deferredRevenue': 5522000000,
#   'deferredRevenueNonCurrent': 0.0,
#   'deferredTaxLiabilitiesNonCurrent': 0.0,
#   'fillingDate': '2019-10-31',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/a10-k20199282019.htm',
#   'goodwill': 0.0,
#   'goodwillAndIntangibleAssets': 0.0,
#   'intangibleAssets': 0.0,
#   'inventory': 4106000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019319000119/0000320193-19-000119-index.htm',
#   'longTermDebt': 91807000000,
#   'longTermInvestments': 0.0,
#   'netDebt': 56732000000,
#   'netReceivables': 45804000000,
#   'otherAssets': 12352000000,
#   'otherCurrentAssets': 12352000000,
#   'otherCurrentLiabilities': 37720000000,
#   'otherLiabilities': 37720000000,
#   'otherNonCurrentAssets': 32978000000,
#   'otherNonCurrentLiabilities': 20958000000,
#   'othertotalStockholdersEquity': 0.0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 37378000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 45898000000,
#   'shortTermDebt': 13769000000,
#   'shortTermInvestments': 51713000000,
#   'symbol': 'AAPL',
#   'taxAssets': 0.0,
#   'taxPayables': 0.0,
#   'totalAssets': 338516000000,
#   'totalCurrentAssets': 162819000000,
#   'totalCurrentLiabilities': 105718000000,
#   'totalDebt': 105576000000,
#   'totalInvestments': 0.0,
#   'totalLiabilities': 248028000000,
#   'totalLiabilitiesAndStockholdersEquity': 338516000000,
#   'totalNonCurrentAssets': 175697000000,
#   'totalNonCurrentLiabilities': 142310000000,
#   'totalStockholdersEquity': 90488000000},
#  {'acceptedDate': '2018-11-05 08:01:40',
#   'accountPayables': 55888000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -3454000000,
#   'cashAndCashEquivalents': 25913000000,
#   'cashAndShortTermInvestments': 66301000000,
#   'commonStock': 40201000000,
#   'date': '2018-09-29',
#   'deferredRevenue': 7543000000,
#   'deferredRevenueNonCurrent': 2797000000,
#   'deferredTaxLiabilitiesNonCurrent': 0.0,
#   'fillingDate': '2018-11-05',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/a10-k20189292018.htm',
#   'goodwill': 0.0,
#   'goodwillAndIntangibleAssets': 0.0,
#   'intangibleAssets': 0.0,
#   'inventory': 3956000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019318000145/0000320193-18-000145-index.htm',
#   'longTermDebt': 93735000000,
#   'longTermInvestments': 170799000000,
#   'netDebt': 79786000000,
#   'netReceivables': 23186000000,
#   'otherAssets': 152694000000,
#   'otherCurrentAssets': 12087000000,
#   'otherCurrentLiabilities': 39293000000,
#   'otherLiabilities': 48914000000,
#   'otherNonCurrentAssets': 22283000000,
#   'otherNonCurrentLiabilities': 2797000000,
#   'othertotalStockholdersEquity': -245000000,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 41304000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 70400000000,
#   'shortTermDebt': 11964000000,
#   'shortTermInvestments': 40388000000,
#   'symbol': 'AAPL',
#   'taxAssets': 0.0,
#   'taxPayables': 0.0,
#   'totalAssets': 365725000000,
#   'totalCurrentAssets': 131339000000,
#   'totalCurrentLiabilities': 115929000000,
#   'totalDebt': 105699000000,
#   'totalInvestments': 211187000000,
#   'totalLiabilities': 258578000000,
#   'totalLiabilitiesAndStockholdersEquity': 365725000000,
#   'totalNonCurrentAssets': 234386000000,
#   'totalNonCurrentLiabilities': 142649000000,
#   'totalStockholdersEquity': 107147000000},
#  {'acceptedDate': '2017-11-03 08:01:37',
#   'accountPayables': 49049000000,
#   'accumulatedOtherComprehensiveIncomeLoss': -41293000000,
#   'cashAndCashEquivalents': 20289000000,
#   'cashAndShortTermInvestments': 74181000000,
#   'commonStock': 35867000000,
#   'date': '2017-09-30',
#   'deferredRevenue': 7548000000,
#   'deferredRevenueNonCurrent': 2836000000,
#   'deferredTaxLiabilitiesNonCurrent': 31504000000,
#   'fillingDate': '2017-11-03',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/a10-k20179302017.htm',
#   'goodwill': 5717000000,
#   'goodwillAndIntangibleAssets': 8015000000,
#   'intangibleAssets': 2298000000,
#   'inventory': 4855000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000032019317000070/0000320193-17-000070-index.htm',
#   'longTermDebt': 97207000000,
#   'longTermInvestments': 53892000000,
#   'netDebt': 95391000000,
#   'netReceivables': 17874000000,
#   'otherAssets': 150984000000,
#   'otherCurrentAssets': 13936000000,
#   'otherCurrentLiabilities': 32240000000,
#   'otherLiabilities': 0.0,
#   'otherNonCurrentAssets': 10162000000,
#   'otherNonCurrentLiabilities': 40415000000,
#   'othertotalStockholdersEquity': 0.0,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 33783000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 98330000000,
#   'shortTermDebt': 18473000000,
#   'shortTermInvestments': 53892000000,
#   'symbol': 'AAPL',
#   'taxAssets': 0.0,
#   'taxPayables': 0.0,
#   'totalAssets': 375319000000,
#   'totalCurrentAssets': 128645000000,
#   'totalCurrentLiabilities': 100814000000,
#   'totalDebt': 115680000000,
#   'totalInvestments': 107784000000,
#   'totalLiabilities': 241272000000,
#   'totalLiabilitiesAndStockholdersEquity': 375319000000,
#   'totalNonCurrentAssets': 246674000000,
#   'totalNonCurrentLiabilities': 140458000000,
#   'totalStockholdersEquity': 134047000000},
#  {'acceptedDate': '2016-10-26 16:42:16',
#   'accountPayables': 37294000000,
#   'accumulatedOtherComprehensiveIncomeLoss': 634000000,
#   'cashAndCashEquivalents': 20484000000,
#   'cashAndShortTermInvestments': 67155000000,
#   'commonStock': 31251000000,
#   'date': '2016-09-24',
#   'deferredRevenue': 8080000000,
#   'deferredRevenueNonCurrent': 2930000000,
#   'deferredTaxLiabilitiesNonCurrent': 0.0,
#   'fillingDate': '2016-10-26',
#   'finalLink': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/a201610-k9242016.htm',
#   'goodwill': 5414000000,
#   'goodwillAndIntangibleAssets': 8620000000,
#   'intangibleAssets': 3206000000,
#   'inventory': 2132000000,
#   'link': 'https://www.sec.gov/Archives/edgar/data/320193/000162828016020309/0001628280-16-020309-index.htm',
#   'longTermDebt': 75427000000,
#   'longTermInvestments': 170430000000,
#   'netDebt': 63048000000,
#   'netReceivables': 15754000000,
#   'otherAssets': 132516000000,
#   'otherCurrentAssets': 8283000000,
#   'otherCurrentLiabilities': 9156000000,
#   'otherLiabilities': 12985000000,
#   'otherNonCurrentAssets': 8757000000,
#   'otherNonCurrentLiabilities': 36074000000,
#   'othertotalStockholdersEquity': -540000000,
#   'period': 'FY',
#   'propertyPlantEquipmentNet': 27010000000,
#   'reportedCurrency': 'USD',
#   'retainedEarnings': 96364000000,
#   'shortTermDebt': 8105000000,
#   'shortTermInvestments': 46671000000,
#   'symbol': 'AAPL',
#   'taxAssets': 26019000000,
#   'taxPayables': 0.0,
#   'totalAssets': 321686000000,
#   'totalCurrentAssets': 106869000000,
#   'totalCurrentLiabilities': 79006000000,
#   'totalDebt': 83532000000,
#   'totalInvestments': 217101000000,
#   'totalLiabilities': 193437000000,
#   'totalLiabilitiesAndStockholdersEquity': 321686000000,
#   'totalNonCurrentAssets': 214817000000,
#   'totalNonCurrentLiabilities': 114431000000,
#   'totalStockholdersEquity': 128249000000}]

# %%
BS = pd.DataFrame.from_dict(BS)
BS
# Out:
#          date  ...                                          finalLink
# 0  2020-09-26  ...  https://www.sec.gov/Archives/edgar/data/320193...
# 1  2019-09-28  ...  https://www.sec.gov/Archives/edgar/data/320193...
# 2  2018-09-29  ...  https://www.sec.gov/Archives/edgar/data/320193...
# 3  2017-09-30  ...  https://www.sec.gov/Archives/edgar/data/320193...
# 4  2016-09-24  ...  https://www.sec.gov/Archives/edgar/data/320193...
#
# [5 rows x 47 columns]

# %%
BS.columns
# Out:
# Index(['date', 'symbol', 'reportedCurrency', 'fillingDate', 'acceptedDate',
#        'period', 'cashAndCashEquivalents', 'shortTermInvestments',
#        'cashAndShortTermInvestments', 'netReceivables', 'inventory',
#        'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
#        'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
#        'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
#        'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
#        'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
#        'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
#        'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
#        'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
#        'otherLiabilities', 'totalLiabilities', 'commonStock',
#        'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
#        'othertotalStockholdersEquity', 'totalStockholdersEquity',
#        'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
#        'totalDebt', 'netDebt', 'link', 'finalLink'],
#       dtype='object')

# %%
BS_our_Columns = ['date', 'cashAndCashEquivalents', 'shortTermInvestments',
       'cashAndShortTermInvestments', 'netReceivables', 'inventory',
       'otherCurrentAssets', 'totalCurrentAssets', 'propertyPlantEquipmentNet',
       'goodwill', 'intangibleAssets', 'goodwillAndIntangibleAssets',
       'longTermInvestments', 'taxAssets', 'otherNonCurrentAssets',
       'totalNonCurrentAssets', 'otherAssets', 'totalAssets',
       'accountPayables', 'shortTermDebt', 'taxPayables', 'deferredRevenue',
       'otherCurrentLiabilities', 'totalCurrentLiabilities', 'longTermDebt',
       'deferredRevenueNonCurrent', 'deferredTaxLiabilitiesNonCurrent',
       'otherNonCurrentLiabilities', 'totalNonCurrentLiabilities',
       'otherLiabilities', 'totalLiabilities', 'commonStock',
       'retainedEarnings', 'accumulatedOtherComprehensiveIncomeLoss',
       'othertotalStockholdersEquity', 'totalStockholdersEquity',
       'totalLiabilitiesAndStockholdersEquity', 'totalInvestments',
       'totalDebt', 'netDebt']

# %%
BS = BS[BS_our_Columns]
BS= BS.T

# %%
BS.columns = BS.iloc[0]
BS
# Out:
# date                                       2020-09-26  ...    2016-09-24
# date                                       2020-09-26  ...    2016-09-24
# cashAndCashEquivalents                    38016000000  ...   20484000000
# shortTermInvestments                      52927000000  ...   46671000000
# cashAndShortTermInvestments               90943000000  ...   67155000000
# netReceivables                            37445000000  ...   15754000000
# inventory                                  4061000000  ...    2132000000
# otherCurrentAssets                        11264000000  ...    8283000000
# totalCurrentAssets                       143713000000  ...  106869000000
# propertyPlantEquipmentNet                 36766000000  ...   27010000000
# goodwill                                            0  ...     5.414e+09
# intangibleAssets                                    0  ...     3.206e+09
# goodwillAndIntangibleAssets                         0  ...      8.62e+09
# longTermInvestments                                 0  ...    1.7043e+11
# taxAssets                                           0  ...    2.6019e+10
# otherNonCurrentAssets                     42522000000  ...    8757000000
# totalNonCurrentAssets                    180175000000  ...  214817000000
# otherAssets                               11264000000  ...  132516000000
# totalAssets                              323888000000  ...  321686000000
# accountPayables                           42296000000  ...   37294000000
# shortTermDebt                             13769000000  ...    8105000000
# taxPayables                                         0  ...             0
# deferredRevenue                            6643000000  ...    8080000000
# otherCurrentLiabilities                   42684000000  ...    9156000000
# totalCurrentLiabilities                  105392000000  ...   79006000000
# longTermDebt                              98667000000  ...   75427000000
# deferredRevenueNonCurrent                           0  ...      2.93e+09
# deferredTaxLiabilitiesNonCurrent                    0  ...             0
# otherNonCurrentLiabilities                26320000000  ...   36074000000
# totalNonCurrentLiabilities               153157000000  ...  114431000000
# otherLiabilities                           4.2684e+10  ...    1.2985e+10
# totalLiabilities                         258549000000  ...  193437000000
# commonStock                               50779000000  ...   31251000000
# retainedEarnings                          14966000000  ...   96364000000
# accumulatedOtherComprehensiveIncomeLoss  -66760000000  ...     634000000
# othertotalStockholdersEquity                        0  ...      -5.4e+08
# totalStockholdersEquity                   65339000000  ...  128249000000
# totalLiabilitiesAndStockholdersEquity    323888000000  ...  321686000000
# totalInvestments                                    0  ...   2.17101e+11
# totalDebt                                112436000000  ...   83532000000
# netDebt                                   74420000000  ...   63048000000
#
# [40 rows x 5 columns]

# %%
BS= BS.iloc[1:]
BS
# Out:
# date                                       2020-09-26  ...    2016-09-24
# cashAndCashEquivalents                    38016000000  ...   20484000000
# shortTermInvestments                      52927000000  ...   46671000000
# cashAndShortTermInvestments               90943000000  ...   67155000000
# netReceivables                            37445000000  ...   15754000000
# inventory                                  4061000000  ...    2132000000
# otherCurrentAssets                        11264000000  ...    8283000000
# totalCurrentAssets                       143713000000  ...  106869000000
# propertyPlantEquipmentNet                 36766000000  ...   27010000000
# goodwill                                            0  ...     5.414e+09
# intangibleAssets                                    0  ...     3.206e+09
# goodwillAndIntangibleAssets                         0  ...      8.62e+09
# longTermInvestments                                 0  ...    1.7043e+11
# taxAssets                                           0  ...    2.6019e+10
# otherNonCurrentAssets                     42522000000  ...    8757000000
# totalNonCurrentAssets                    180175000000  ...  214817000000
# otherAssets                               11264000000  ...  132516000000
# totalAssets                              323888000000  ...  321686000000
# accountPayables                           42296000000  ...   37294000000
# shortTermDebt                             13769000000  ...    8105000000
# taxPayables                                         0  ...             0
# deferredRevenue                            6643000000  ...    8080000000
# otherCurrentLiabilities                   42684000000  ...    9156000000
# totalCurrentLiabilities                  105392000000  ...   79006000000
# longTermDebt                              98667000000  ...   75427000000
# deferredRevenueNonCurrent                           0  ...      2.93e+09
# deferredTaxLiabilitiesNonCurrent                    0  ...             0
# otherNonCurrentLiabilities                26320000000  ...   36074000000
# totalNonCurrentLiabilities               153157000000  ...  114431000000
# otherLiabilities                           4.2684e+10  ...    1.2985e+10
# totalLiabilities                         258549000000  ...  193437000000
# commonStock                               50779000000  ...   31251000000
# retainedEarnings                          14966000000  ...   96364000000
# accumulatedOtherComprehensiveIncomeLoss  -66760000000  ...     634000000
# othertotalStockholdersEquity                        0  ...      -5.4e+08
# totalStockholdersEquity                   65339000000  ...  128249000000
# totalLiabilitiesAndStockholdersEquity    323888000000  ...  321686000000
# totalInvestments                                    0  ...   2.17101e+11
# totalDebt                                112436000000  ...   83532000000
# netDebt                                   74420000000  ...   63048000000
#
# [39 rows x 5 columns]

# %%
total_Assets = BS.iloc[16]
common_Size = BS/total_Assets
common_Size
# Out:
# date                                    2020-09-26  ...  2016-09-24
# cashAndCashEquivalents                    0.117374  ...    0.063677
# shortTermInvestments                      0.163411  ...    0.145082
# cashAndShortTermInvestments               0.280785  ...    0.208759
# netReceivables                            0.115611  ...   0.0489732
# inventory                                0.0125383  ...  0.00662758
# otherCurrentAssets                       0.0347775  ...   0.0257487
# totalCurrentAssets                        0.443712  ...    0.332215
# propertyPlantEquipmentNet                 0.113515  ...   0.0839639
# goodwill                                         0  ...   0.0168301
# intangibleAssets                                 0  ...  0.00996624
# goodwillAndIntangibleAssets                      0  ...   0.0267963
# longTermInvestments                              0  ...    0.529802
# taxAssets                                        0  ...   0.0808832
# otherNonCurrentAssets                     0.131286  ...   0.0272222
# totalNonCurrentAssets                     0.556288  ...    0.667785
# otherAssets                              0.0347775  ...    0.411942
# totalAssets                                      1  ...           1
# accountPayables                           0.130588  ...    0.115933
# shortTermDebt                            0.0425116  ...   0.0251954
# taxPayables                                      0  ...           0
# deferredRevenue                          0.0205102  ...   0.0251177
# otherCurrentLiabilities                   0.131786  ...   0.0284625
# totalCurrentLiabilities                   0.325396  ...      0.2456
# longTermDebt                              0.304633  ...    0.234474
# deferredRevenueNonCurrent                        0  ...  0.00910826
# deferredTaxLiabilitiesNonCurrent                 0  ...           0
# otherNonCurrentLiabilities               0.0812627  ...     0.11214
# totalNonCurrentLiabilities                 0.47287  ...    0.355723
# otherLiabilities                          0.131786  ...   0.0403654
# totalLiabilities                          0.798267  ...    0.601322
# commonStock                                0.15678  ...   0.0971475
# retainedEarnings                         0.0462073  ...    0.299559
# accumulatedOtherComprehensiveIncomeLoss  -0.206121  ...  0.00197087
# othertotalStockholdersEquity                     0  ... -0.00167866
# totalStockholdersEquity                   0.201733  ...    0.398678
# totalLiabilitiesAndStockholdersEquity            1  ...           1
# totalInvestments                                 0  ...    0.674885
# totalDebt                                 0.347145  ...    0.259669
# netDebt                                   0.229771  ...    0.195992
#
# [39 rows x 5 columns]
